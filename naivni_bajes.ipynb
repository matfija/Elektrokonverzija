# %% [markdown]
# ## Ucitavanje podataka

# %%
import pandas as pd

df = pd.read_csv(
        'elektroprecisceno.csv',
         index_col=0
     )
df
# Out:
#       godine  stariji  Pol  indikacija:  ukupno  trajanje  frekvenca  Blok  \
# Broj
# 1         78        1    1            1       5         5          0     3
# 2         61        0    1            2      24         1          7     0
# 3         65        1    1            1       4         4          0     3
# 4         64        0    1            1     288         2          7     0
# 5         65        1    2            1      48         3          9     0
# ...      ...      ...  ...          ...     ...       ...        ...   ...
# 646       61        0    1            2       2         2          0     3
# 647       58        0    1            2      12         2          0     3
# 648       72        1    2            1      20        20          6     0
# 649       39        0    1            2      48         1          9     0
# 650       60        0    1            2      10        10          0     3
#
#       dimenzija  EDD  ...  Sotalol  Digoksin  ASA  OAKT  Plavix  Statin  \
# Broj                  ...
# 1            42   56  ...        0         0    0     2       0       0
# 2            42   59  ...        0         0    0     2       0       0
# 3            47   55  ...        0         0    0     2       0       0
# 4            50   50  ...        0         0    0     2       0       0
# 5            49   61  ...        0         0    0     2       0       1
# ...         ...  ...  ...      ...       ...  ...   ...     ...     ...
# 646          36   54  ...        0         0    0     2       0       0
# 647          45   57  ...        0         0    0     3       0       1
# 648          43   66  ...        0         1    0     3       0       0
# 649          35   48  ...        0         0    0     1       0       0
# 650          45   59  ...        0         0    0     3       0       1
#
#       Implantiran  Vreme  sinhroni,  Elektrokonverzija
# Broj
# 1               1      2          2               True
# 2               0     -1          2               True
# 3               1      3          2               True
# 4               0     -1          2               True
# 5               0     -1          2               True
# ...           ...    ...        ...                ...
# 646             1      2          2               True
# 647             1      2          2               True
# 648             0     -1          2               True
# 649             0     -1          2               True
# 650             1      2          2               True
#
# [147 rows x 49 columns]

# %% [markdown]
# ## Podela podataka na trening i test

# %%
from sklearn.model_selection import train_test_split

X = df.iloc[:,:-1]
y = df.iloc[:,-1]

X_train, X_test, y_train, y_test = train_test_split(X,y, random_state=0, stratify=y, test_size=0.7)

# %% [markdown]
# ## Normalizacija podataka

# %%
from sklearn.preprocessing import MinMaxScaler

scaler = MinMaxScaler()  
scaler = scaler.fit(X_train)
X_train = scaler.transform(X_train) 
X_test = scaler.transform(X_test)

# %% [markdown]
# ## Primena Naivnog Bajesa ( GaussianNB, ComplementNB)

# %%
from sklearn.naive_bayes import GaussianNB, ComplementNB
from sklearn.metrics import confusion_matrix, classification_report

gnb = GaussianNB()
gnb.fit(X_train,y_train)

y_pred = gnb.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 5  7]
#  [41 50]]
#               precision    recall  f1-score   support
#
#        False       0.11      0.42      0.17        12
#         True       0.88      0.55      0.68        91
#
#     accuracy                           0.53       103
#    macro avg       0.49      0.48      0.42       103
# weighted avg       0.79      0.53      0.62       103

# %%
cnb = ComplementNB()
cnb.fit(X_train,y_train)

y_pred = cnb.predict(X_test)
print(confusion_matrix(y_test,y_pred))
print(classification_report(y_test,y_pred))
# Out:
# [[ 2 10]
#  [14 77]]
#               precision    recall  f1-score   support
#
#        False       0.12      0.17      0.14        12
#         True       0.89      0.85      0.87        91
#
#     accuracy                           0.77       103
#    macro avg       0.51      0.51      0.50       103
# weighted avg       0.80      0.77      0.78       103
